# %%
#BeautifulSoup cheatsheet: http://akul.me/blog/2016/beautifulsoup-cheatsheet/

from splinter import Browser
from bs4 import BeautifulSoup as bs
import time

import requests
from fake_useragent import UserAgent
from lxml import html
from flask import Flask
from flask_pymongo import PyMongo

ua = UserAgent()

# %%
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "c:/Users/JBENITEZ/Desktop/RutgersDataScience/GitHub_Homework/14_Homework_WebScraping/chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
#using fake user agent to get data to disguise that request is being sent from lines of code (i.e. imitating request from browser)
#make soup out of any website

header = {'user-agent':ua.chrome}
mars_page = requests.get('https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars',headers=header)
#https://mars.nasa.gov/news/
soup = bs(mars_page.content,'lxml') # html.parser

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]> <html class="no-js ie ie9" lang="en"> <![endif]-->
# <!--[if IE 8]> <html class="no-js ie ie8" lang="en"> <![endif]-->
# <html>
#  <!-- START HEADER: "DEFAULT" -->
#  <head>
#   <meta charset="utf-8"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <title>
#    Space Images
#   </title>
#   <link href="/assets/stylesheets/manifest.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/assets/stylesheets/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script src="/assets/javascripts/public_manifest.js" type="text/javascript">
#   </script>
#   <script src="/assets/javascripts/vendor/jquery.fancybox.js" type="text/javascript">
#   </script>
# ...

# %%
# Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. Assign the text to variables that you can reference later.

news_title = soup.find("div",class_="content_title").text
print(news_title)
news_p = soup.find("div", class_="rollover_description_inner").text
print(news_p)
# Out:
# 										  Her Desher Vallis
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-c3d8d0937b9e> in <module>()
#       3 news_title = soup.find("div",class_="content_title").text
#       4 print(news_title)
# ----> 5 news_p = soup.find("div", class_="rollover_description_inner").text
#       6 print(news_p)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Visit the url for JPL Featured Space Image here: https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars
# Use splinter to navigate the site and find the image url for the current Featured Mars Image and assign the url string to a variable called featured_image_url.
# Make sure to find the image url to the full size .jpg image.
# Make sure to save a complete url string for this image.

header = {'user-agent':ua.chrome}
jpl_url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
browser.visit(jpl_url)

#featured_image_url = 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA16225_hires.jpg'
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# ...

# %%
# Out:
#   File "<ipython-input-44-23298ec02806>", line 1
#     JPL Mars Space Images - Featured Image
#            ^
# SyntaxError: invalid syntax
